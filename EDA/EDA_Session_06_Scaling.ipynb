# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

visa_df=pd.read_csv(r"C:\Users\vaish\Documents\NareshIT\GEN_AI\Data_Files\Visadataset.csv")
visa_df

num = visa_df.select_dtypes(exclude='str').columns
cat = visa_df.select_dtypes(include='str').columns

# %% [markdown]
# **Why Scaling**
#
# - Scaling  presreve the numerical statbility across the columns
#     - EX: Age : 20    Salary: 50000    Exp: 2
#     - different colums having the different scale(limit)
#     - we want to keep all the columns under same limit
#     - if we dont keep under same scale some ML algo feels salary is the important column
#         - because of the heighest value
#
# - **Faster training**
#
#
#     - Some of ML algorithms like **KNN,KMEANS,SVM** are distance based algorithms
#
#     - if we lower the values the calculation are fast
#
#     - In every Model development will do math calculations
#
#     - In order to increase the fastness(optimization) Scaling is very helpful

# %% [markdown]
# **Z Scale**
#
# <img src="https://onemoneyway.com/wp-content/uploads/2024/09/Z-Score_-Definition-Formula-Calculation-Interpretation.jpeg" jsaction="" class="sFlh5c FyHeAf iPVvYb" style="max-width: 435px; height: 151px; margin: 0px; width: 185px;" alt="Understanding z-scores: A guide for businesses to improve data analysis" jsname="kn3ccd">

# %%
visa_df['prevailing_wage']
# Out:
# 0           592.2029
# 1         83425.6500
# 2        122996.8600
# 3         83434.0300
# 4        149907.3900
#             ...
# 25475     77092.5700
# 25476    279174.7900
# 25477    146298.8500
# 25478     86154.7700
# 25479     70876.9100
# Name: prevailing_wage, Length: 25480, dtype: float64

# %%
wage_data=visa_df['prevailing_wage']
# step-1 : wage_mean=wage_data.mean()
# step-2 : wage_sd
# step-3 : Nr=wage_data-wage_mean
# step-4 : Nr/wage_sd

# %%
wage_mean=wage_data.mean()
wage_sd=wage_data.std()
Nr=wage_data-wage_mean
wage_z=Nr/wage_sd

# %%
# old_data: wage_data
# z_data: wage_z
plt.figure(figsize=(10,6))
plt.subplot(2,2,1).hist(wage_data)
plt.subplot(2,2,2).hist(wage_z)
plt.subplot(2,2,3).boxplot(wage_data,vert=False)
plt.subplot(2,2,4).boxplot(wage_z,vert=False)
plt.show()

# %%
- sklearn 
    - preprocessing
        - StandardScalar
            - fit_transform

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
wage_data_ss=ss.fit_transform(visa_df[['prevailing_wage']])

# %%
plt.figure(figsize=(10,6))
plt.subplot(2,2,1).hist(wage_data)
plt.subplot(2,2,2).hist(wage_data_ss)
plt.subplot(2,2,3).boxplot(wage_data,vert=False)
plt.subplot(2,2,4).boxplot(wage_data_ss,vert=False)
plt.show()

# %% [markdown]
# **Normalization**
#
# <img class="VeBrne" alt="" src="https://encrypted-tbn3.gstatic.com/images?q=tbn:ANd9GcSn7IL8vm2FlJzsFToAazoy2EbfUJU22rLef5JKLTUm6asUQuRg" jscontroller="UBXHI" jsaction="DdQV6c:QT8fkf" data-csiid="Aop7auDrOYyvwcsPp_v2oQY_13" data-atf="4" data-iml="1786481156905">

# %%
# step-1: wage_min
# step-2: wage_max
# step-3: Nr=wage_data-wage_min
# step-4: Dr=wage_max-wage_min
# step-5: wage_norm=Nr/Dr

# %%
# StandardScalar is called as a Z score
# MinMaxScalar is called as Norm 0 to 1
- sklearn
    - preprocessing
        - MinMaxScalar
            - fit_transform
