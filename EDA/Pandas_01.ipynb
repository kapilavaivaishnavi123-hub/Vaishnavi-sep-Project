# %%
# important
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Names=['Ramesh','Suresh','Satish','Mahesh']
Age=[20,22,24,26]

# %% [markdown]
# **Step-1:Create a Dataframe**

# %%
Extract transform load
ETL is a process 
EDA data Analysis    # both are different

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# pd.DataFrame(data,index,columns,dtype,copy)

pd.DataFrame(Names) 
# pd.DataFrame(Names,'Names') # Names assume as index
# pd.DataFrame(Names,columns=''Names) # Columns array
pd.DataFrame(Names,columns=['Names'])
# Out:
#     Names
# 0  Ramesh
# 1  Suresh
# 2  Satish
# 3  Mahesh

# %%
# pd.DataFrame(data,index,columns,dtype,copy)
pd.DataFrame(Names)
pd.DataFrame(Names,columns=['Names'])
pd.DataFrame(Names,
             index=['A','B','C','D'],
            columns=['Names'])
# Out:
#     Names
# A  Ramesh
# B  Suresh
# C  Satish
# D  Mahesh

# %%
Names=['Ramesh','Suresh','Satish','Mahesh']
Age=[20,22,24,26]
DATA=[Names,Age]
pd.DataFrame(DATA).T
# Out:
#         0   1
# 0  Ramesh  20
# 1  Suresh  22
# 2  Satish  24
# 3  Mahesh  26

# %%
Names=['Ramesh','Suresh','Satish','Mahesh']
Age=[20,22,24,26]
DATA=zip(Names,Age)
pd.DataFrame(DATA,columns=['Names','Age'])
# Out:
#     Names  Age
# 0  Ramesh   20
# 1  Suresh   22
# 2  Satish   24
# 3  Mahesh   26

# %% [markdown]
# **Step-2: Add a new column to already an existed df**

# %%
Names=['Ramesh','Suresh','Satish','Mahesh']
Age=[20,22,24,26]
DATA=zip(Names,Age)
df=pd.DataFrame(DATA,columns=['Names','Age'])

# %%
df
# Out:
#     Names  Age
# 0  Ramesh   20
# 1  Suresh   22
# 2  Satish   24
# 3  Mahesh   26

# %%
df[col_name]
# Selection
# Updation
# Creation

# %%
df['Names']
# Out:
# 0    Ramesh
# 1    Suresh
# 2    Satish
# 3    Mahesh
# Name: Names, dtype: str

# %%
df['Age']=[30,32,34,36]
df
# Out:
#     Names  Age
# 0  Ramesh   30
# 1  Suresh   32
# 2  Satish   34
# 3  Mahesh   36

# %%
df['City']=['Hyd','Pune','Blr','Bihata']
df
# Out:
#     Names  Age    City
# 0  Ramesh   30     Hyd
# 1  Suresh   32    Pune
# 2  Satish   34     Blr
# 3  Mahesh   36  Bihata

# %%
df['Gender']=['Male','Male','Male','Male']
df
# Out:
#     Names  Age    City Gender
# 0  Ramesh   30     Hyd   Male
# 1  Suresh   32    Pune   Male
# 2  Satish   34     Blr   Male
# 3  Mahesh   36  Bihata   Male

# %%
df()

# %% [markdown]
# **30 July 2026**

# %% [markdown]
# - created a dataframe with one column
# - learned how to add a column names
# - learned how to change the index
# - created a dataframe with two colums using zip
# - understood how to select, update and creat new column with already existed dataframe

# %% [markdown]
# **Step-3 : How to add data to empry dataframe**

# %%
df=pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df["Names"]=["Ramesh","suresh","Satish"]
df["Age"]=[20,24,26]
df["City"]=["Hyd","Blr","Chennai"]
df
# Out:
#     Names  Age     City
# 0  Ramesh   20      Hyd
# 1  suresh   24      Blr
# 2  Satish   26  Chennai

# %% [markdown]
# **Step-4 : Create a Dataframe using Dictionary**

# %%
d={"Names":["Ramesh","suresh","Satish"],
   "Age":[20,24,26],
    "City":["Hyd","Blr","Chennai"]}
d
# Out:
# {'Names': ['Ramesh', 'suresh', 'Satish'],
#  'Age': [20, 24, 26],
#  'City': ['Hyd', 'Blr', 'Chennai']}

# %%
df=pd.DataFrame(d)
df
# Keys become colums 
# Values become rows
# Out:
#     Names  Age     City
# 0  Ramesh   20      Hyd
# 1  suresh   24      Blr
# 2  Satish   26  Chennai

# %%
d={'Names':'Ramesh',
   'Age':20,
    'City':'Hyd'}
df=pd.DataFrame(d)  # Error : If using all scalar values, you must pass an index

# %%
d={'Names':'Ramesh',
   'Age':20,
    'City':'Hyd'}
df=pd.DataFrame(d,index=[0,1,2])
df
# Out:
#     Names  Age City
# 0  Ramesh   20  Hyd
# 1  Ramesh   20  Hyd
# 2  Ramesh   20  Hyd

# %% [markdown]
# **Step-5: drop a new column**

# %%
df["Names"]=["Ramesh","suresh","Satish"]
df["Age"]=[20,24,26]
df["City"]=["Hyd","Pune","Delhi"]
df
# Out:
#     Names  Age   City
# 0  Ramesh   20    Hyd
# 1  suresh   24   Pune
# 2  Satish   26  Delhi

# %%
df.drop(Lables,axis=0,index,columns,inplace=True) # Index
# default behaviour
# default it is consider index or column
# Doc string shift+tab

# %%
df.drop('City')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df.drop('City')
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:6300, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6142 def drop(
#    6143     self,
#    6144     labels: IndexLabel | ListLike = None,
#    (...)   6151     errors: IgnoreRaise = "raise",
#    6152 ) -> DataFrame | None:
#    6153     """
#    6154     Drop specified labels from rows or columns.
#    6155
#    (...)   6298             weight  1.0     0.8
#    6299     """
# -> 6300     return super().drop(
#    6301         labels=labels,
#    6302         axis=axis,
#    6303         index=index,
#    6304         columns=columns,
#    6305         level=level,
#    6306         inplace=inplace,
#    6307         errors=errors,
#    6308     )
#
# ...

# %%
df.drop('City',axis=1)
# inplace  = False
# inplace =  True overwrite the output in same df
# Out:
#     Names  Age
# 0  Ramesh   20
# 1  suresh   24
# 2  Satish   26

# %%
df.drop(colums=['City'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df.drop(colums=['City'])
#
# TypeError: DataFrame.drop() got an unexpected keyword argument 'colums'. Did you mean 'columns'?

# %%
df.drop(2)
# Out:
#     Names  Age  City
# 0  Ramesh   20   Hyd
# 1  suresh   24  Pune

# %%
df.drop(2,axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df.drop(2,axis=1)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:6300, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6142 def drop(
#    6143     self,
#    6144     labels: IndexLabel | ListLike = None,
#    (...)   6151     errors: IgnoreRaise = "raise",
#    6152 ) -> DataFrame | None:
#    6153     """
#    6154     Drop specified labels from rows or columns.
#    6155
#    (...)   6298             weight  1.0     0.8
#    6299     """
# -> 6300     return super().drop(
#    6301         labels=labels,
#    6302         axis=axis,
#    6303         index=index,
#    6304         columns=columns,
#    6305         level=level,
#    6306         inplace=inplace,
#    6307         errors=errors,
#    6308     )
#
# ...

# %%
df.drop(2,axis=0)
# Out:
#     Names  Age  City
# 0  Ramesh   20   Hyd
# 1  suresh   24  Pune

# %%
df.drop(index=[2])
# Out:
#     Names  Age  City
# 0  Ramesh   20   Hyd
# 1  suresh   24  Pune

# %%
df.drop(lables,axis)
df.drop('City',axis=0) # Index drop error
df.drop('City',axis=1) # column drop

df.drop(columns=['City'])
df.drop(2) # 2 == column 2 == index
df.drop(2,axis=0) # label 2 it is a index
df.drop('City') # City is a index
df.drop('City',axis=1)

# %% [markdown]
# **Step-5 : Rename**

# %% [markdown]
# - rename the column
# - rename the index

# %%
df["Names"]=["Ramesh","suresh","Satish"]
df["Age"]=[20,24,26]
df["City"]=["Hyd","Pune","Delhi"]
df
# Out:
#     Names  Age   City
# 0  Ramesh   20    Hyd
# 1  suresh   24   Pune
# 2  Satish   26  Delhi

# %%
# df.rename(mapper)
# mapper means dictionary
c={'City':'Citi'}
df.rename(c, axis=1) # 1 level

df.rename(columns=c) # 2 Level
# Out:
#     Names  Age   Citi
# 0  Ramesh   20    Hyd
# 1  suresh   24   Pune
# 2  Satish   26  Delhi

# %% [markdown]
# **Step-7 : Save the dataframe**

# %% [markdown]
# - dataframe can be save into : .csv format
# - .xlsx format
# - where you want to save:directory
# - on what name you want save : name of the file
# - on what extension you can use : .csv,.xlsx
# - different location : "C:\Users\vaish\Documents\NareshIT\GEN_AI\df1.csv"
# - same location : no need to provide directory: 'df1.csv'

# %%
df.to_csv
df.to_excel

# %%
df.to_csv(r"C:\Users\vaish\Documents\NareshIT\GEN_AI\df1.csv",index=False)
df.to_csv('df1.csv',index=False)

# %%
df.to_csv:(r"C:\Users\vaish\Documents\NareshIT\GEN_AI\df2.csv")

# %% [markdown]
# **Step-8 : How to read a Dataframe**

# %%
pd.read_csv(r"C:\Users\vaish\Documents\NareshIT\GEN_AI\df1.csv")
pd.read_csv('df1.csv')
# Out:
#     Names  Age   City
# 0  Ramesh   20    Hyd
# 1  suresh   24   Pune
# 2  Satish   26  Delhi

# %%
pd.read_excel(<full path>)
