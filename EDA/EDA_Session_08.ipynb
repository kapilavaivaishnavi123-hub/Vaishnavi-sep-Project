# %% [markdown]
# - Data read
# - Data cleaning
# - EDA
#     - Data analysis
#     - Feature engineering
#         - scaling
#         - transformations
#         - encoding
#     - Feature selection
# - Model development
# - Model evaluation
# - Model tuning
# - Model deployment

# %% [markdown]
# **Supervised Learning**
#
# Data has both input columns and Output column
# Data has labelled
#
# For example loan prediction
#         - He opted the Loan (Yes)
#         - Not opted the Loan (No)
# For example Visa dataset
#         Case status is the Target
#         - Certified
#         - Denied
#
# Supervised Learning : Data has both input and output column
#
# - Classification :  Output columns is Categorical data type
#       - EX: yes or No, Certified or Denied , Dog vs Cat
#       - Logistic Regression
#       - Decison Tree
#       - Naive Bayes
#       - K - Nearest Neighbours(KNN)
#       - Ensembel methods
#           - Bagging : Random Forest
#           - Boosting : Adaboost, Gradient Boost, XG boost
#       - Support Vector Machines
#       - Recommendation Engine
#
# - Regression: Output column is Numerical data type
#         - Forecast : share price prediction, sales prediction, revenue
#         - Linear Regression
#         - Lasso Regression (Regularization Methods)
#         - Ridge Regression (Regularization Methods)
#         - Elastic net regression
#
# Unsupervised learning :
#
# - we have data , we dont have a specific target
# - simply we dont have any output column
# - Cluster or segmentation algorithms
#     - K - means
#     - Heirarchical cluster
#     - Density based cluster

# %% [markdown]
# **Linear regression**
#
# Linear regression is a regression method
# Linear regression has under the supervised learning
# Linear regression has both input data and ouput data, but output data in numers
# Regression means forecast methods
#
# Use case :
# you wants to spend some money on advertisment so that sales might be increase
# - TV
# - NP
# - SM
# - Increase the sales
#
#   input columns = {TV,NP,SM} output = {sales} Assume some data
#     TV(x1)        NP(x2)       SM(x3)       sales(y)
#      200           100          150           2000
#      150           50           250           1500
#      300           450          500           3000
#      500           550          600            ?
#
# based on past data model should understand the patterns
# patterns means relation between input and output data
# when a new data pass to the model, it should provide output
#
#
#             you make one equation
#         Sales = 1*TV +1 *NP + 1* SM
#
#
# Draw back :
#
# we are providing an equal importance to all th input featuers
# in a real time each feature has different impact on output column
# this impact generally we called as weighatge
#
#
#                     Sales = w1*TV + w2*Np + w3*SM
#                         y = w1*x1 + w2*x2 + w3*x3
#                                 or
#                         y = beta1*x1 +beta2*x2 +beta3*x3
#
#        eventhough there is no advertisment still we can get some Sales
#        that denoted by bias beta0
#                         y = beta0 + beta1*x1 + beta2*x2 + beta3*x3
